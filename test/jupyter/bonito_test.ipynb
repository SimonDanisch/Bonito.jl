# %%
# Bonito smoke test - verifies rendering in JupyterLab
# Reads a random token from file to prove this is a fresh execution
using Bonito
token = read(joinpath(@__DIR__, "test_token.txt"), String) |> strip
App() do session
    Bonito.DOM.div("BONITO_TEST_SUCCESS_$token"; id="bonito-test-output")
end |> display
